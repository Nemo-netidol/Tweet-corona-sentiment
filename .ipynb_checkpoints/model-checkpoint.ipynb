# %%
import pandas as pd
import nltk
from nltk.stem import WordNetLemmatizer
import string
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import re
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, f1_score, r2_score, recall_score, ConfusionMatrixDisplay
import pickle
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from imblearn.over_sampling import SMOTE

# %%
df1 = pd.read_csv('Corona_NLP_train.csv', encoding='ISO-8859-1')
df2 = pd.read_csv('Corona_NLP_test.csv', encoding='ISO-8859-1')
df = pd.concat([df1, df2])
df = df[(df['Sentiment'] == 'Positive') | (df['Sentiment'] == 'Negative')]
df['Len'] = df['OriginalTweet'].apply(len)
# df = df.dropna()
# df = df[0:100]
df
# Out:
#       UserName  ScreenName                   Location     TweetAt  \
# 1         3800       48752                         UK  16-03-2020
# 2         3801       48753                  Vagabonds  16-03-2020
# 3         3802       48754                        NaN  16-03-2020
# 5         3804       48756  ÃT: 36.319708,-82.363649  16-03-2020
# 6         3805       48757       35.926541,-78.753267  16-03-2020
# ...        ...         ...                        ...         ...
# 3784      3785       48737          Paraparaumu Beach  16-03-2020
# 3790      3791       48743           Cincinnati, Ohio  16-03-2020
# 3792      3793       48745            Washington D.C.  16-03-2020
# 3793      3794       48746                  Israel ??  16-03-2020
# 3794      3795       48747             Farmington, NM  16-03-2020
#
#                                           OriginalTweet Sentiment  Len
# 1     advice Talk to your neighbours family to excha...  Positive  237
# 2     Coronavirus Australia: Woolworths to give elde...  Positive  131
# 3     My food stock is not the only one which is emp...  Positive  306
# 5     As news of the regionÂs first confirmed COVID...  Positive  250
# 6     Cashier at grocery store was sharing his insig...  Positive  180
# ...                                                 ...       ...  ...
# 3784  Just been through K?piti New World which is bu...  Positive  291
# 3790  Even though the Law Library is closed, ALL sub...  Positive  217
# 3792  @RicePolitics @MDCounties Craig, will you call...  Negative  215
# 3793  Meanwhile In A Supermarket in Israel -- People...  Positive  127
# 3794  Did you panic buy a lot of non-perishable item...  Negative  213
#
# [23327 rows x 7 columns]

# %%
df.isna().sum()
# Out:
# UserName            0
# ScreenName          0
# Location         4918
# TweetAt             0
# OriginalTweet       0
# Sentiment           0
# Len                 0
# dtype: int64

# %%
sns.displot(df, x='Sentiment', hue='Sentiment')

# %% [markdown]
# # Preprocessing

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
stopword_list = set(stopwords.words('english'))

# %%
extra_punct = [
    ',', '.', '"', ':', ')', '(', '!', '?', '|', ';', "'", '$', '&',
    '/', '[', ']', '>', '%', '=', '#', '*', '+', '\\', '•',  '~', '@', '£',
    '·', '_', '{', '}', '©', '^', '®', '`',  '<', '→', '°', '€', '™', '›',
    '♥', '←', '×', '§', '″', '′', 'Â', '█', '½', 'à', '…', '“', '★', '”',
    '–', '●', 'â', '►', '−', '¢', '²', '¬', '░', '¶', '↑', '±', '¿', '▾',
    '═', '¦', '║', '―', '¥', '▓', '—', '‹', '─', '▒', '：', '¼', '⊕', '▼',
    '▪', '†', '■', '’', '▀', '¨', '▄', '♫', '☆', 'é', '¯', '♦', '¤', '▲',
    'è', '¸', '¾', 'Ã', '⋅', '‘', '∞', '∙', '）', '↓', '、', '│', '（', '»',
    '，', '♪', '╩', '╚', '³', '・', '╦', '╣', '╔', '╗', '▬', '❤', 'ï', 'Ø',
    '¹', '≤', '‡', '√', '«', '»', '´', 'º', '¾', '¡', '§', '£', '₤']

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
def clean_stopword(text):
    return " ".join([word.lower() for word in word_tokenize(text) if word not in stopword_list])

# %%
def clean_special_character(text):
    return re.sub('[^a-zA-Z\s]', "", text)

# %%
# lemmatization
lemmatizer = WordNetLemmatizer()
def lemmatize(sentence):
    
    return

# %%
# remove punctuation 
def clean_punctuation(sentence):
    for punc in string.punctuation:
        if punc in sentence:
            sentence = sentence.replace(punc, " ")
    return sentence.strip()

# %%
# POS tag

# %%
df['OriginalTweet'] = df['OriginalTweet'].apply(clean_stopword)

# %%
df['OriginalTweet'] = df['OriginalTweet'].apply(clean_special_character)

# %%
df['OriginalTweet'] = df['OriginalTweet'].apply(clean_punctuation)

# %%
df['Len'] = df['OriginalTweet'].apply(len)

# %%
encoder = LabelEncoder()

df['Sentiment'] = encoder.fit_transform(df['Sentiment'])

# %%
df
# Out:
#       UserName  ScreenName                   Location     TweetAt  \
# 1         3800       48752                         UK  16-03-2020
# 2         3801       48753                  Vagabonds  16-03-2020
# 3         3802       48754                        NaN  16-03-2020
# 5         3804       48756  ÃT: 36.319708,-82.363649  16-03-2020
# 6         3805       48757       35.926541,-78.753267  16-03-2020
# ...        ...         ...                        ...         ...
# 3784      3785       48737          Paraparaumu Beach  16-03-2020
# 3790      3791       48743           Cincinnati, Ohio  16-03-2020
# 3792      3793       48745            Washington D.C.  16-03-2020
# 3793      3794       48746                  Israel ??  16-03-2020
# 3794      3795       48747             Farmington, NM  16-03-2020
#
#                                           OriginalTweet  Sentiment  Len
# 1     advice Talk to your neighbours family to excha...          1  237
# 2     Coronavirus Australia: Woolworths to give elde...          1  131
# 3     My food stock is not the only one which is emp...          1  306
# 5     As news of the regionÂs first confirmed COVID...          1  250
# 6     Cashier at grocery store was sharing his insig...          1  180
# ...                                                 ...        ...  ...
# 3784  Just been through K?piti New World which is bu...          1  291
# 3790  Even though the Law Library is closed, ALL sub...          1  217
# 3792  @RicePolitics @MDCounties Craig, will you call...          0  215
# 3793  Meanwhile In A Supermarket in Israel -- People...          1  127
# 3794  Did you panic buy a lot of non-perishable item...          0  213
#
# [23327 rows x 7 columns]

# %% [markdown]
# # SMOTE

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer, TfidfVectorizer

# %%
tfidf = TfidfVectorizer()
X = tfidf.fit_transform(df['OriginalTweet'])
y = df['Sentiment']

# %%
sm = SMOTE(random_state=1)

# %%
X_res, y_res = sm.fit_resample(X, y)

# %%
y_res
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 24733    0
# 24734    0
# 24735    0
# 24736    0
# 24737    0
# Name: Sentiment, Length: 24738, dtype: int32

# %%
df_resampled = pd.DataFrame()
df_resampled['Sentiment'] = y_res
df_resampled['SentimentLabel'] =  encoder.inverse_transform(y_res)
df_resampled
# Out:
#        Sentiment SentimentLabel
# 0              1       Positive
# 1              1       Positive
# 2              1       Positive
# 3              1       Positive
# 4              1       Positive
# ...          ...            ...
# 24733          0       Negative
# 24734          0       Negative
# 24735          0       Negative
# 24736          0       Negative
# 24737          0       Negative
#
# [24738 rows x 2 columns]

# %%
sns.displot(df_resampled, x='SentimentLabel', hue='SentimentLabel')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Word cloud

# %%
texts = " ".join([word for word in df['OriginalTweet']])

# %%
wc = WordCloud(max_words=100, colormap='magma', background_color='white')
wc.generate(texts)
plt.figure(figsize=(10,10))
plt.imshow(wc)
plt.show()

# %% [markdown]
# # Modeling

# %%
cv = CountVectorizer()

# %%
X = df['OriginalTweet']

# %%
X_count_vectorizer = cv.fit_transform( X )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [100], in <cell line: 1>()
# ----> 1 X_count_vectorizer = cv.fit_transform( X )
#
# NameError: name 'cv' is not defined

# %%
tfidfTransformer = TfidfTransformer()

X = tfidfTransformer.fit_transform(X_count_vectorizer)

# %%
cv.get_feature_names_out()

# %%
y = encoder.fit_transform(df['Sentiment'])
y

# %%
encoder.classes_

# %%
X_train, X_test, y_train, y_test = train_test_split(X_res, y_res, test_size=0.2, random_state=42)

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier()

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_predict = rf.predict(X_test)

# %%
print(f'Accuracy : {accuracy_score(y_test, y_predict)}')
print(f'r2 score : {r2_score(y_test, y_predict)}')
# Out:
# Accuracy : 0.7237267582861763
# r2 score : -0.1051234807835364

# %%
cm = confusion_matrix(y_test, y_predict)
cm
# Out:
# array([[1741,  720],
#        [ 647, 1840]], dtype=int64)

# %%
cm_display = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=encoder.inverse_transform(rf.classes_))
cm_display.plot(xticks_rotation=45)
plt.show()

# %% [markdown]
# # SVM

# %%
from sklearn.svm import SVC

# %%
clf = SVC()

# %%
clf.fit(X_train, y_train)
# Out:
# SVC()

# %%
y_predict = clf.predict(X_test)

# %%
print(f'Accuracy : {accuracy_score(y_test, y_predict)}')
print(f'r2 score : {r2_score(y_test, y_predict)}')
# Out:
# Accuracy : 0.799514955537591
# r2 score : 0.19803767890470514

# %%
cm = confusion_matrix(y_test, y_predict)
cm
# Out:
# array([[1912,  549],
#        [ 443, 2044]], dtype=int64)

# %%
cm_display = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=encoder.inverse_transform(clf.classes_))
cm_display.plot(xticks_rotation=45)
plt.show()

# %% [markdown]
# # Naive Bayes

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
clf = MultinomialNB()

# %%
clf.fit(X_train, y_train)
# Out:
# MultinomialNB()

# %%
y_predict = clf.predict(X_test)

# %%
print(f'Accuracy : {accuracy_score(y_test, y_predict)}')
print(f'r2 score : {r2_score(y_test, y_predict)}')
# Out:
# Accuracy : 0.7261519805982215
# r2 score : -0.09542232367351255

# %%
cm = confusion_matrix(y_test, y_predict)
cm
# Out:
# array([[1882,  579],
#        [ 776, 1711]], dtype=int64)

# %%
cm_display = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=encoder.inverse_transform(clf.classes_))
cm_display.plot(xticks_rotation=45)
plt.show()

# %%
message = 'Covid made world economic gradually worse'
vectorized_message = tfidf.transform([message])
# vectorized_message
clf.predict((vectorized_message))
encoder.inverse_transform(clf.predict((vectorized_message)))
# Out:
# array(['Negative'], dtype=object)
